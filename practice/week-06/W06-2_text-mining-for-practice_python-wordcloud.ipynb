# %% [markdown]
# # TEXT MINING for PRACTICE: 워드클라우드
# ---

# %%
import sys
# !{sys.executable} -m pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /Users/seojungwon/anaconda3/lib/python3.6/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/seojungwon/anaconda3/lib/python3.6/site-packages (from wordcloud) (1.15.4)
# Requirement already satisfied: pillow in /Users/seojungwon/anaconda3/lib/python3.6/site-packages (from wordcloud) (5.4.1)

# %%
# wordcloud 패키지를 불러옵니다.
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
noun_string = "사과 바나나 바나나 사과 사과 파인애플"

# %%
# 워드클라우드를 생성하고 파일로 저장합니다.

# 워드클라우드 옵션을 선택합니다.
font_path="data/NanumGothic.ttf"  #폰트
background_color="white"      #배경색
margin=10                     #모서리 여백 넓이
min_font_size=10              #최소 글자 크기
max_font_size=150             #최대 글자 크기
width=500                     #이미지 가로 크기
height=500                    #이미지 세로 크기
wc = WordCloud(font_path=font_path, background_color=background_color, \
               margin=margin, min_font_size=min_font_size, \
               max_font_size=max_font_size, width=width, height=height)
wc.generate(noun_string)

# 생성된 워드클라우드를 이미지로 생성합니다.
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Q 이전 과제의 내용을 이용해 첫 번째 문서의 Top100 단어에 대한 word cloud를 만들어보자!
